# %% [markdown]
# <a href="https://colab.research.google.com/github/FernanLobo/Proyecto-1/blob/main/Ejercicios_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/19WfNFwr8eu0YK3MGQh4RBczbKfbcqvgI?usp=sharing).

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# difinir función
print ('Hola Soy Fan del Fedelobo')

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# difinir función
len([1, 2, 3, 4, 5])

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# difinir función
sorted([5, 4, 2, 1, 8])

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
# difinir función
round(6.193858517)

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# difinir función
min((3, 8, 12, 144, 0.2))

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# difinir función
numero = int(input("Ingresa un numero:"))
def cuadrado(numero):
  return numero ** 2

cuadrado(numero)

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# difinir función
numero = int(input('Ingresa un número: '))

def par(numero):
    if numero % 2 == 0:
        print('Par')
    else:
        print('Impar')

par(numero)

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# difinir función
numero = int(input('Ingresa un número: '))

def factorial(numero):
    if numero == 0:
        return 1
    else:
        return numero * factorial(numero - 1)

factorial(numero)

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas
l1 = [23, 56]
l2 = [3, 4, 5]

# %%
# difinir función
l1 = [23, 56]
l2 = [3, 4, 5]
def unir(l1, l2):
    listaF = l1 + l2
    return listaF

unir(l1, l2)

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario
diccionario = {'Industrial': 'Calidad', 'Mecánica': 'Máquinas', 'Sistemas': 'Computadora'}

# %%
# difinir función
clave = input('Ingrese una clave: ')

def buscar(diccionario, clave):
    return diccionario.get(clave)

buscar(diccionario, clave)

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda
nombre_1 = input("Ingresa el nombre del contacto: ")
telefono_1 = input("Ingresa el telefono del contacto: ")
correo_1 = input("Ingresa el correo del contacto: ")

contacto_1 = {
    "Nombre": nombre_1,
    "Teléfono": telefono_1,
    "Correo": correo_1
}

nombre_2 = input("Ingresa el nombre del contacto: ")
telefono_2 = input("Ingresa el telefono del contacto: ")
correo_2 = input("Ingresa el correo del contacto: ")

contacto_2 = {
    "Nombre": nombre_2,
    "Teléfono": telefono_2,
    "Correo": correo_2
}

nombre_3 = input("Ingresa el nombre del contacto: ")
telefono_3 = input("Ingresa el telefono del contacto: ")
correo_3 = input("Ingresa el correo del contacto: ")

contacto_3 = {
    "Nombre": nombre_3,
    "Teléfono": telefono_3,
    "Correo": correo_3
}

# Crear agenda
agenda = [contacto_1, contacto_2, contacto_3]

print("Agenda inicial:")
print(agenda)

# Modificar datos del contacto 3
contacto_3["Teléfono"] = "9518888888"
contacto_3["Correo"] = "lopez@gmail.com"

print("\nAgenda actualizada:")
print(agenda)

# Imprimir todos los contactos
print("Agenda completa:")
print("Agenda completa:")
for i, contacto in enumerate(agenda):
  print(f"--- Contacto {i+1} ---")
  for key, value in contacto.items():
    print(f"{key}: {value}")
  print("--------------------")
print (agenda)
nombre = input("Ingresa el nombre del contacto: ")
telefono = input("Ingresa el teléfono del contacto: ")
correo = input("Ingresa el correo del contacto: ")

contacto = {
    "Nombre": nombre,
    "Teléfono": telefono,
    "Correo": correo
}

agenda.append(contacto)

print("Contacto creado con éxito")
print("Consultar contacto")

buscar = input("Ingresa el nombre del contacto a consultar: ")

encontrado = False

for contacto in agenda:
    if contacto["Nombre"] == buscar:
        print("Contacto encontrado:")
        print(contacto)
        encontrado = True
        break

if not encontrado:
    print("Contacto no encontrado")
print("Actualizar contacto")

buscar = input("Ingresa el nombre del contacto a actualizar: ")

for contacto in agenda:

    if contacto["Nombre"] == buscar:

        print("Contacto encontrado:")
        print(contacto)

        while True:

            print("\nMenú de actualización")
            print("1. Cambiar nombre")
            print("2. Cambiar teléfono")
            print("3. Cambiar correo")
            print("4. Salir")

            opcion = input("Selecciona una opción: ")

            if opcion == "1":
                nuevo_nombre = input("Ingresa el nuevo nombre: ")
                contacto["Nombre"] = nuevo_nombre
                print(contacto)

            elif opcion == "2":
                nuevo_telefono = input("Ingresa el nuevo teléfono: ")
                contacto["Teléfono"] = nuevo_telefono
                print(contacto)

            elif opcion == "3":
                nuevo_correo = input("Ingresa el nuevo correo: ")
                contacto["Correo"] = nuevo_correo
                print(contacto)

            elif opcion == "4":
                break

            else:
                print("Contacto no encontrado")

        break

else:
    print("Contacto no encontrado")
print("\n--- Eliminar contacto ---")

buscar = input("Ingresa el nombre del contacto a eliminar: ")

for contacto in agenda:

    if contacto["Nombre"] == buscar:
        agenda.remove(contacto)
        print("Contacto eliminado")
        break

else:
    print("Contacto no encontrado")
# Out:
# Ingresa el nombre del contacto: Karim
# Ingresa el telefono del contacto: 9515661210
# Ingresa el correo del contacto: karim@gmail.com
# Ingresa el nombre del contacto: Fedelobo
# Ingresa el telefono del contacto: 865123827
# Ingresa el correo del contacto: fedelobo@gmail.com
# Ingresa el nombre del contacto: Fernando
# Ingresa el telefono del contacto: 91827636467
# Ingresa el correo del contacto: fer@gmail.com
# Agenda inicial:
# [{'Nombre': 'Karim', 'Teléfono': '9515661210', 'Correo': 'karim@gmail.com'}, {'Nombre': 'Fedelobo', 'Teléfono': '865123827', 'Correo': 'fedelobo@gmail.com'}, {'Nombre': 'Fernando', 'Teléfono': '91827636467', 'Correo': 'fer@gmail.com'}]
#
# Agenda actualizada:
# [{'Nombre': 'Karim', 'Teléfono': '9515661210', 'Correo': 'karim@gmail.com'}, {'Nombre': 'Fedelobo', 'Teléfono': '865123827', 'Correo': 'fedelobo@gmail.com'}, {'Nombre': 'Fernando', 'Teléfono': '9518888888', 'Correo': 'lopez@gmail.com'}]
# Agenda completa:
# Agenda completa:
# --- Contacto 1 ---
# Nombre: Karim
# Teléfono: 9515661210
# Correo: karim@gmail.com
# --------------------
# --- Contacto 2 ---
# Nombre: Fedelobo
# Teléfono: 865123827
# Correo: fedelobo@gmail.com
# --------------------
# --- Contacto 3 ---
# Nombre: Fernando
# Teléfono: 9518888888
# Correo: lopez@gmail.com
# --------------------
# [{'Nombre': 'Karim', 'Teléfono': '9515661210', 'Correo': 'karim@gmail.com'}, {'Nombre': 'Fedelobo', 'Teléfono': '865123827', 'Correo': 'fedelobo@gmail.com'}, {'Nombre': 'Fernando', 'Teléfono': '9518888888', 'Correo': 'lopez@gmail.com'}]
# Ingresa el nombre del contacto: Ceci
# Ingresa el teléfono del contacto: 91723636171
# Ingresa el correo del contacto: ceci@gmail.com
# Contacto creado con éxito
# Consultar contacto
# Ingresa el nombre del contacto a consultar: Fedelobo
# Contacto encontrado:
# {'Nombre': 'Fedelobo', 'Teléfono': '865123827', 'Correo': 'fedelobo@gmail.com'}
# Actualizar contacto
# Ingresa el nombre del contacto a actualizar: Karim
# Contacto encontrado:
# {'Nombre': 'Karim', 'Teléfono': '9515661210', 'Correo': 'karim@gmail.com'}
#
# Menú de actualización
# 1. Cambiar nombre
# 2. Cambiar teléfono
# 3. Cambiar correo
# 4. Salir
# Selecciona una opción: 4
#
# --- Eliminar contacto ---
# Ingresa el nombre del contacto a eliminar: Fernando
# Contacto eliminado

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
def menu_crud():
    print("\nMenú CRUD - Agenda")
    print("1. Ver agenda")
    print("2. Crear contacto")
    print("3. Consultar contacto")
    print("4. Actualizar contacto")
    print("5. Eliminar contacto")
    print("6. Salir menú")

menu_crud()
# Out:
# Menú CRUD - Agenda
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
# Crear función mostrar agenda
def ver_agenda(agenda):

    print("\n--- Agenda completa ---")

    for i, contacto in enumerate(agenda):
        print(f"\n--- Contacto {i+1} ---")

        for key, value in contacto.items():
            print(f"{key}: {value}")

        print("--------------------")
print(ver_agenda(agenda))
# Out:
# --- Agenda completa ---
#
# --- Contacto 1 ---
# Nombre: Karim
# Teléfono: 9515661210
# Correo: karim@gmail.com
# --------------------
#
# --- Contacto 2 ---
# Nombre: Fedelobo
# Teléfono: 865123827
# Correo: fedelobo@gmail.com
# --------------------
#
# --- Contacto 3 ---
# Nombre: Ceci
# Teléfono: 91723636171
# Correo: ceci@gmail.com
# --------------------
# None

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
def crear_contacto():
    nombre = input("Ingresa el nombre del contacto: ")
    telefono = input("Ingresa el teléfono del contacto: ")
    correo = input("Ingresa el correo del contacto: ")

    contacto = {
        "Nombre": nombre,
        "Teléfono": telefono,
        "Correo": correo
    }
    print("Contacto creado con éxito")
    return contacto
print(crear_contacto())
# Out:
# Ingresa el nombre del contacto: Roberto
# Ingresa el teléfono del contacto: 915661210
# Ingresa el correo del contacto: rob@gmail.com}
# Contacto creado con éxito
# {'Nombre': 'Roberto', 'Teléfono': '915661210', 'Correo': 'rob@gmail.com}'}

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
def consultar_contacto(agenda):
    buscar = input("Ingresa el nombre del contacto a consultar: ")
    encontrado = False
    for contacto in agenda:
        if contacto["Nombre"] == buscar:
            print("Contacto encontrado:")
            print(contacto)
            encontrado = True
            break
    if not encontrado:
        print("Contacto no encontrado")
print(consultar_contacto(agenda))
# Out:
# Ingresa el nombre del contacto a consultar: Karim
# Contacto encontrado:
# {'Nombre': 'Karim', 'Teléfono': '9515661210', 'Correo': 'karim@gmail.com'}
# None

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
def menu_actualizar_contacto():
    print("\nMenú actualizar contacto:")
    print("1. Actualizar nombre")
    print("2. Actualizar teléfono")
    print("3. Actualizar correo")
    print("4. Salir del menú")

menu_actualizar_contacto()
# Out:
# Menú actualizar contacto:
# 1. Actualizar nombre
# 2. Actualizar teléfono
# 3. Actualizar correo
# 4. Salir del menú

# %% [markdown]
#    * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto
def buscar_contacto(agenda, nombre):

    for contacto in agenda:

        if contacto["Nombre"] == nombre:
            return contacto

    return None
print(buscar_contacto(agenda, nombre))
# Out:
# {'Nombre': 'Ceci', 'Teléfono': '91723636171', 'Correo': 'ceci@gmail.com'}

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto
def cambiar_nombre(contacto):

    nuevo_nombre = input("Ingresa el nuevo nombre: ")
    contacto["Nombre"] = nuevo_nombre
    print(contacto)
print(cambiar_nombre(contacto))
# Out:
# Ingresa el nuevo nombre: Ceci
# {'Nombre': 'Ceci', 'Teléfono': '9518888888', 'Correo': 'lopez@gmail.com'}
# None

# %%
# Crear función actualizar telefono para actualizar contacto
def cambiar_telefono(contacto):

    nuevo_telefono = input("Ingresa el nuevo teléfono: ")
    contacto["Teléfono"] = nuevo_telefono
    print(contacto)
print(cambiar_telefono(contacto))
# Out:
# Ingresa el nuevo teléfono: 9512344567
# {'Nombre': 'Ceci', 'Teléfono': '9512344567', 'Correo': 'lopez@gmail.com'}
# None

# %%
# Crear función actualizar correo para actualizar contacto
def cambiar_correo(contacto):

    nuevo_correo = input("Ingresa el nuevo correo: ")
    contacto["Correo"] = nuevo_correo
    print(contacto)
print(cambiar_correo(contacto))
# Out:
# Ingresa el nuevo correo: garcia@gmail.com
# {'Nombre': 'Ceci', 'Teléfono': '9512344567', 'Correo': 'garcia@gmail.com'}
# None

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto
def actualizar_contacto(agenda):

    nombre = input("Ingresa el nombre del contacto a actualizar: ")

    contacto = buscar_contacto(agenda, nombre)

    if contacto is None:
        print("Contacto no encontrado")
        return

    while True:

        print("\nMenú de actualización")
        print("1. Cambiar nombre")
        print("2. Cambiar teléfono")
        print("3. Cambiar correo")
        print("4. Salir")

        opcion = input("Selecciona una opción: ")

        if opcion == "1":
            cambiar_nombre(contacto)

        elif opcion == "2":
            cambiar_telefono(contacto)

        elif opcion == "3":
            cambiar_correo(contacto)

        elif opcion == "4":
            break

        else:
            print("Opción no encontrada")
print(actualizar_contacto(agenda))
# Out:
# Ingresa el nombre del contacto a actualizar: Karim
#
# Menú de actualización
# 1. Cambiar nombre
# 2. Cambiar teléfono
# 3. Cambiar correo
# 4. Salir
# Selecciona una opción: 2
# Ingresa el nuevo teléfono: 918273627281
# {'Nombre': 'Karim', 'Teléfono': '918273627281', 'Correo': 'karim@gmail.com'}
#
# Menú de actualización
# 1. Cambiar nombre
# 2. Cambiar teléfono
# 3. Cambiar correo
# 4. Salir
# Selecciona una opción: 4
# None

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto
def eliminar_contacto(agenda):

    buscar = input("Ingresa el nombre del contacto a eliminar: ")

    for contacto in agenda:

        if contacto["Nombre"] == buscar:
            agenda.remove(contacto)
            print("Contacto eliminado")
            return

    print("Contacto no encontrado")
print(eliminar_contacto(agenda))
# Out:
# Ingresa el nombre del contacto a eliminar: Karim
# Contacto eliminado
# None

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda
def ejecutar_menu(agenda):

    while True:

        menu_crud()

        opcion = input("Selecciona una opción: ")

        if opcion == "1":
            ver_agenda(agenda)

        elif opcion == "2":
            crear_contacto(agenda)

        elif opcion == "3":
            consultar_contacto(agenda)

        elif opcion == "4":
            actualizar_contacto(agenda)

        elif opcion == "5":
            eliminar_contacto(agenda)

        elif opcion == "6":
            print("Saliendo del menú...")
            break

        else:
            print("Opción no encontrada")
print(ejecutar_menu(agenda))
# Out:
# Menú CRUD - Agenda
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
# Selecciona una opción: 1
#
# --- Agenda completa ---
#
# --- Contacto 1 ---
# Nombre: Fernando
# Teléfono: 81723646181
# Correo: bdbfenrkf
# --------------------
#
# --- Contacto 2 ---
# Nombre: wefewarfwe
# Teléfono: fefwfwe
# Correo: fesfe4sf
# --------------------
#
# --- Contacto 3 ---
# Nombre: fesf
# Teléfono: efsfef
# Correo: fesf
# --------------------
#
# Menú CRUD - Agenda
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
# Selecciona una opción: 1
#
# --- Agenda completa ---
#
# --- Contacto 1 ---
# Nombre: Fernando
# Teléfono: 81723646181
# Correo: bdbfenrkf
# --------------------
#
# --- Contacto 2 ---
# Nombre: wefewarfwe
# Teléfono: fefwfwe
# Correo: fesfe4sf
# --------------------
#
# --- Contacto 3 ---
# Nombre: fesf
# Teléfono: efsfef
# Correo: fesf
# --------------------
#
# Menú CRUD - Agenda
# 1. Ver agenda
# 2. Crear contacto
# 3. Consultar contacto
# 4. Actualizar contacto
# 5. Eliminar contacto
# 6. Salir menú
# Selecciona una opción: 6
# Saliendo del menú...
# None
